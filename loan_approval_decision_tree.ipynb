# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("loan_approval_dataset.csv")
data
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
data.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
e=LabelEncoder()
data[" loan_status"]=e.fit_transform(data[" loan_status"])

# %%
data
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
data[" education"]=e.fit_transform(data[" education"])

# %%
data[" self_employed"]=e.fit_transform(data[" self_employed"])

# %%
x=data[[' no_of_dependents', ' education', ' self_employed',
       ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
       ' residential_assets_value']]
y=data[" loan_status"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=model.predict(x_test)

# %%
pred
# Out:
# array([1, 0, 1, ..., 0, 1, 0])

# %%
from sklearn.metrics import accuracy_score

# %%
score=accuracy_score(y_test,pred)

# %%
score
# Out:
# 0.9836065573770492

# %%
values=[4,1,0,600000,1500000,20,315,2000000]
columns=[' no_of_dependents', ' education', ' self_employed',
       ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
       ' residential_assets_value']
index=[1,2,3,4,5,6,7,8]

# %%
input_data=pd.DataFrame([values],columns=columns)

# %%
val=model.predict(input_data)

# %%
if val==1:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
model.predict([[4,1,0,600000,1500000,20,315,2000000]])
# Out:
# c:\Users\lavan\anaconda\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
# Save the model
import pickle 
with open('loan_approval_decision_tree.pkl', 'wb') as model_file:
    pickle.dump(model, model_file)

# %%
with open('loan_approval_model.pkl', 'wb') as model_file:
    pickle.dump({'model': model, 'encoder': e}, model_file)

# %%
import joblib

# Save the model and encoder
joblib.dump(model, 'loan_approval_model.joblib')
joblib.dump(e, 'label_encoder.joblib')
# Out:
# ['label_encoder.joblib']

# %%
from joblib import dump, load

# Save the model to a file
dump(model, 'loan_approval_model.joblib')

# Load the model from the file
loaded_model = load('loan_approval_model.joblib')

# %%
loaded_model.predict([[4,1,0,600000,1500000,20,315,2000000]])
# Out:
# c:\Users\lavan\anaconda\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
import joblib

print("Joblib version:", joblib.__version__)
# Out:
# Joblib version: 1.3.2

# %%
pip install --upgrade joblib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import joblib

print("Joblib version:", joblib.__version__)
# Out:
# Joblib version: 1.3.2

# %%
import pickle 
with open('loan.pkl', 'wb') as model_file:
    pickle.dump(model, model_file)

# %%
import pickle

# Open the file in binary read mode ('rb')
with open("loan_approval_model.pkl", 'rb') as file:
    # Load the pickled model
    loan_model = pickle.load(file)
